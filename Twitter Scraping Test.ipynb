# %%
from src.scrapeTwitter import *

# %%
KEY_PHRASES = ["climate change", "sustainability", "technology"]
START_DATE = "2021-01-01"
END_DATE = "2021-08-30"
MAX_TWEETS_PER_PHRASE = 10000

MIN_FOLLOWERS = 10000
MAX_TWEETS_PER_USER = 200

NUMBER_OF_TOPICS = 3
NO_TOP_WORDS = 5

# %%
test = scrapeTwitter(KEY_PHRASES, START_DATE, END_DATE, MAX_TWEETS_PER_PHRASE,
                     MIN_FOLLOWERS, MAX_TWEETS_PER_USER, NUMBER_OF_TOPICS,
                     NO_TOP_WORDS)
# Out:
# Scraped 0 of 3 key phrases.
# Scraped 1 of 3 key phrases.
# Scraped 2 of 3 key phrases.
# There are 2303 candidate users.
# 1 users have been processed.
# 21 users have been processed.
# 41 users have been processed.
# 61 users have been processed.
# 81 users have been processed.
# 101 users have been processed.
# 121 users have been processed.
# 141 users have been processed.
# 161 users have been processed.
# 181 users have been processed.
# 201 users have been processed.
# 221 users have been processed.
# 241 users have been processed.
# 261 users have been processed.
# 281 users have been processed.
# 301 users have been processed.
# 321 users have been processed.
# 341 users have been processed.
# 361 users have been processed.
# 381 users have been processed.
# 401 users have been processed.
# 421 users have been processed.
# 441 users have been processed.
# 461 users have been processed.
# 481 users have been processed.
# 501 users have been processed.
# ...

# %%
test
# Out:
#               Username  FollowerCount  Verified  Max Scores  Avg Scores  \
# 29           Fox26Mike          24968      True    0.823529    0.259559
# 32        EliLikesRice          35051     False    0.923077    0.239471
# 34       mikesbloggity          44214      True    0.941176    0.242052
# 55       AllanMargolin          33040     False    0.900000    0.254479
# 61     AndyFillmoreHFX          15418      True    0.833333    0.235164
# ...                ...            ...       ...         ...         ...
# 29945        parismarx          20063     False    0.941176    0.234053
# 29962     gabrieloguda         241118      True    0.571429    0.212711
# 29975  starsandstripes         258978      True    0.500000    0.224016
# 29981         KOINNews         129550      True    0.833333    0.219303
# 30002          bsn_sni          23269      True    0.588235    0.225260
#
#                                                LDA Model
# ...

# %%
test[test["Max Scores"] > 0.941]
# Out:
#              Username  FollowerCount  Verified  Max Scores  Avg Scores  \
# 34      mikesbloggity          44214      True    0.941176    0.242052
# 127        cliffkuang          12422      True    0.941176    0.232818
# 203           tify330          14314     False    0.941176    0.259186
# 591        FastCoTech          11351      True    0.941176    0.256266
# 939     amywestervelt          43042      True    0.941176    0.230299
# ...               ...            ...       ...         ...         ...
# 29127  GerberKawasaki         176458      True    0.941176    0.238087
# 29537   apexworldnews          28232     False    0.941176    0.226797
# 29757     Brasilmagic          90174     False    0.941176    0.255311
# 29771          jrlind          11186      True    0.941176    0.220838
# 29945       parismarx          20063     False    0.941176    0.234053
#
#                                                LDA Model
# 34     LatentDirichletAllocation(n_components=3, rand...
# ...
